# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

# %%
f = open('pos.out','r')

# %%
array  = []
particle = []
xpos1 = []
ypos1 = []
zpos1 = []
xpos2 = []
ypos2 = []
zpos2 = []
time1 = []
count = 0

# %%
for line in f:
    count = count + 1
    l = line.split()
    if count <= 1000:
        time1.append(repr(float(l[0])))
        xpos1.append(repr(float(l[1])))
        ypos1.append(repr(float(l[2])))
        zpos1.append(repr(float(l[3])))
    else:
        xpos2.append(repr(float(l[1])))
        ypos2.append(repr(float(l[2])))
        zpos2.append(repr(float(l[3])))

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(xpos1,ypos1, label = 'FCC')
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in resizeEvent(self, event)
#     336         self.figure.set_size_inches(winch, hinch)
#     337         FigureCanvasBase.resize_event(self)
# --> 338         self.draw()
#     339         self.update()
#     340         QtWidgets.QWidget.resizeEvent(self, event)
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
# ...
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in idle_draw(*args)
#     425         def idle_draw(*args):
#     426             try:
# --> 427                 self.draw()
#     428             finally:
#     429                 self._idle = True
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# /usr/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     274
#     275         # Then rest
# --> 276         Axes.draw(self, renderer)
#     277
#     278     def get_axis_position(self):
#
# /usr/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/lib/python3.4/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     123     def draw(self, renderer):
#     124         xs3d, ys3d, zs3d = self._verts3d
# --> 125         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
#     126         self.set_data(xs, ys)
#     127         lines.Line2D.draw(self, renderer)
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     197     """
#     198     vec = vec_pad_ones(xs, ys, zs)
# --> 199     return proj_transform_vec(vec, M)
#     200
#     201 def proj_transform_clip(xs, ys, zs, M):
#
# /usr/lib/python3.4/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_vec(vec, M)
#     156
#     157 def proj_transform_vec(vec, M):
# --> 158     vecw = np.dot(M, vec)
#     159     w = vecw[3]
#     160     # clip here..
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'
